# %% [markdown]
# # 01_entrenar_y_generar_modelo_final.ipynb
#
# Notebook generado desde `01_entrenar_y_generar_modelo_final.ipynb`.

# %%
import subprocess
import sys
from pathlib import Path


REPO_ROOT = Path.cwd().resolve().parent
SUPPORT_ROOT = REPO_ROOT / "soporte"


STEPS = [
    [sys.executable, "-m", "jupyter", "execute", "soporte/codigo/2_feature_engineering.ipynb"],
    [sys.executable, "-m", "jupyter", "execute", "soporte/codigo/3_catboost_best_submit.ipynb"],
    [sys.executable, "-m", "jupyter", "execute", "soporte/codigo/5_catboost_feature_selection.ipynb"],
    [sys.executable, "-m", "jupyter", "execute", "soporte/codigo/7_catboost_top60_hypercv.ipynb"],
    [sys.executable, "-m", "jupyter", "execute", "soporte/codigo/11_catboost_top60_postprocess.ipynb"],
    [sys.executable, "-m", "jupyter", "execute", "soporte/codigo/13_extratrees_models.ipynb"],
    [sys.executable, "-m", "jupyter", "execute", "soporte/codigo/14_extratrees_blends.ipynb"],
    [sys.executable, "-m", "jupyter", "execute", "soporte/codigo/16_hardcode_genre.ipynb"],
    [sys.executable, "-m", "jupyter", "execute", "soporte/codigo/17_second_subgenre_probe.ipynb"],
]

# %%
def run_step(command):
    print("\n" + "=" * 100)
    print("Ejecutando:", " ".join(command))
    print("=" * 100)
    subprocess.run(command, cwd=REPO_ROOT, check=True)

# %%
def main():
    train_path = REPO_ROOT / "datos_raw" / "base_train.csv"
    test_path = REPO_ROOT / "datos_raw" / "base_val.csv"
    if not train_path.exists() or not test_path.exists():
        raise FileNotFoundError(
            "Faltan datos_raw/base_train.csv y/o datos_raw/base_val.csv."
        )

    for command in STEPS:
        run_step(command)

    final_path = SUPPORT_ROOT / "Submits" / "hardcode_rank_neo60_progressive_down_24.csv"
    print("\nModelo final reproducible generado:")
    print(final_path)

# %%
if __name__ == "__main__":
    main()
